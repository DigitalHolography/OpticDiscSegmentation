# %% [markdown]
# # YOLO
# This notebook uses UltraLytics' YOLO library that can be found here :
# - [ultralytics homepage](https://www.ultralytics.com)
# - [ultralytics documentation](https://docs.ultralytics.com/)
# - [ultralytics github](https://github.com/ultralytics/ultralytics)
#
# It is used for eye detection, optic disk detection and eye side detection.
# This notebook is used for training.

# %%
from ultralytics import YOLO

# %%
# Load a pretrained YOLOv11 model (Nano version, fastest)
model = YOLO("models/yolo11x-cls.pt")

# %%
# Train
model.train(
    data="datasets/classification",
    epochs=100,
    imgsz=640,
    project="runs/train",
    name="eye_side_classification",
    optimizer='SGD',
)

# %%
# export to MATLAB ONNX (opset version 17 important !)
model = YOLO("runs/train/eye_side_classification8/weights/best.pt")
model.export(format="onnx", opset=17)
